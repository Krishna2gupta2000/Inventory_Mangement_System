# %% [markdown]
# # **IMS**
# ## *Inventory Management System*

# %% [markdown]
#  TO ADD PRODUCT INTO INVENTORY

# %%
### ADD Inventory

# %%
import json

f= open("records.json","r")
readata = f.read()
records = json.loads(readata)
num_add = int(input("How many product you want to Add Record! \n Be carefull about name spelling while input \n  "))
counter_id = len(records) +1000

lst_store =[]
# Out:
# How many product you want to Add Record!
#  Be carefull about name spelling while input
#   1

# %%
for i in range(num_add):
    prod_name = input("Enter Product name: ")
    qty = int(input("Enter quantity: "))
    price = int(input("Enter Price: "))
    category = input("Enter Category: ")
    weight = float(input("Enter the weight in Kg: "))
    store = {"name":prod_name,"quantity":qty,"Price":price,"Category":category,"Weight":weight}
    lst_store.append(store)
    print("\n <--------------------------------------------------------------------> \n")

lst_store
# Out:
# Enter Product name: GUITAR
# Enter quantity: 3
# Enter Price: 100
# Enter Category: lol
# Enter the weight in Kg: 10
#
#  <-------------------------------------------------------------------->
# [{'Category': 'lol',
#   'Price': 100,
#   'Weight': 10.0,
#   'name': 'GUITAR',
#   'quantity': 3}]

# %%
 
for check in lst_store:
  new =1
  for record in records.values():
    if(record['name'].lower() == check['name'].lower()):
      record['quantity'] += check['quantity']
      new = 0
  if(new==1):
    records[str(counter_id)]={"name":check['name'],"quantity":check['quantity'],"Price":check['Price'],"Category":check['Category'],"Weight":check['Weight']}
    counter_id += counter_id


  

#record.update({counter_id:{"name":prod_name,"quantity":qty,"Price":price,"Category":category,"Weight":weight}})

# %%
f = open("records.json","w")
save = json.dumps(records)
f.write(save)
f.close()

# %%
f= open("records.json","r")
readata = f.read()
rec = json.loads(readata)
rec
# Out:
# {'1000': {'Category': 'oniment',
#   'Price': 80,
#   'Weight': 0.001,
#   'name': 'zandu Balm',
#   'quantity': 120},
#  '1001': {'Category': 'Pen',
#   'Price': 10,
#   'Weight': 0.001,
#   'name': 'Raynolds Waterproff pen',
#   'quantity': 14},
#  '1002': {'Category': 'Talcum',
#   'Price': 300,
#   'Weight': 0.25,
#   'name': 'Wild Stone',
#   'quantity': 6},
#  '1003': {'Category': 'drink',
#   'Price': 1.36,
#   'Weight': 499.07,
#   'name': 'Apple Cider vinegar',
#   'quantity': 73},
#  '1004': {'Category': 'Snacks',
#   'Price': 40.32,
#   'Weight': 0.53,
#   'name': 'Pasta',
#   'quantity': 57},
#  '1005': {'Category': 'Food',
#   'Price': 889.17,
#   'Weight': 0.71,
#   'name': 'Rice',
#   'quantity': 89},
#  '1006': {'Category': 'Food',
#   'Price': 10.99,
#   'Weight': 77.35,
#   'name': 'Bread',
#   'quantity': 95},
#  '1007': {'Category': 'Food',
#   'Price': 739.14,
#   'Weight': 2.91,
#   'name': 'All-purpose flour',
#   'quantity': 1},
#  '1008': {'Category': 'Food',
#   'Price': 2.54,
#   'Weight': 0.19,
#   'name': 'Red kidney beans',
#   'quantity': 3},
#  '1009': {'Category': 'Food',
#   'Price': 790.18,
#   'Weight': 0.09,
#   'name': 'White beans',
#   'quantity': 92},
#  '1010': {'Category': 'Food',
#   'Price': 0.59,
#   'Weight': 0.07,
#   'name': 'Green lentils',
#   'quantity': 28},
#  '1011': {'Category': 'Spices',
#   'Price': 0.79,
#   'Weight': 0.09,
#   'name': 'Salt',
#   'quantity': 40},
#  '1012': {'Category': 'Spices',
#   'Price': 3.27,
#   'Weight': 0.0,
#   'name': 'Pepper',
#   'quantity': 68},
#  '1013': {'Category': 'Spices',
#   'Price': 303.32,
#   'Weight': 0.1,
#   'name': 'Basil',
#   'quantity': 50},
#  '1014': {'Category': 'Spices',
#   'Price': 36.64,
#   'Weight': 7.51,
#   'name': 'Oregano',
#   'quantity': 15},
#  '1015': {'Category': 'Spices',
#   'Price': 696.98,
#   'Weight': 0.0,
#   'name': 'Coriander',
#   'quantity': 87},
#  '1016': {'Category': 'Spices',
#   'Price': 6.11,
#   'Weight': 7.25,
#   'name': 'Cumin',
#   'quantity': 29},
#  '1017': {'Category': 'Spices',
#   'Price': 1.53,
#   'Weight': 0.0,
#   'name': 'Stock cubes',
#   'quantity': 12},
#  '1018': {'Category': 'Snacks',
#   'Price': 45.1,
#   'Weight': 916.78,
#   'name': 'Honey',
#   'quantity': 66},
#  '1019': {'Category': 'drink',
#   'Price': 76.56,
#   'Weight': 478.76,
#   'name': 'Vinegar',
#   'quantity': 65},
#  '1020': {'Category': 'Food',
#   'Price': 78.84,
#   'Weight': 2.98,
#   'name': 'Sugar',
#   'quantity': 99},
#  '1021': {'Category': 'drink',
#   'Price': 1.75,
#   'Weight': 0.7,
#   'name': 'Milk',
#   'quantity': 95},
#  '1022': {'Category': 'Food',
#   'Price': 0.33,
#   'Weight': 35.41,
#   'name': 'Eggs',
#   'quantity': 23},
#  '1023': {'Category': 'Food',
#   'Price': 19.27,
#   'Weight': 0.0,
#   'name': 'Cheese',
#   'quantity': 96},
#  '1024': {'Category': 'Food',
#   'Price': 881.65,
#   'Weight': 0.95,
#   'name': 'Yogurt',
#   'quantity': 64},
#  '1025': {'Category': 'drink',
#   'Price': 1.87,
#   'Weight': 2.06,
#   'name': 'Cooking oil',
#   'quantity': 30},
#  '1026': {'Category': 'Food',
#   'Price': 836.22,
#   'Weight': 0.0,
#   'name': 'Butter',
#   'quantity': 92},
#  '1027': {'Category': 'Decoration',
#   'Price': 5.55,
#   'Weight': 0.0,
#   'name': 'Stencil',
#   'quantity': 70},
#  '1028': {'Category': 'Decoration',
#   'Price': 9.65,
#   'Weight': 56.15,
#   'name': 'Hour Glass',
#   'quantity': 69},
#  '1029': {'Category': 'Decoration',
#   'Price': 507.07,
#   'Weight': 0.09,
#   'name': 'Guitar',
#   'quantity': 32},
#  '1030': {'Category': 'Decoration',
#   'Price': 955.71,
#   'Weight': 0.0,
#   'name': 'Action Figurine',
#   'quantity': 7},
#  '1031': {'Category': 'Pen',
#   'Price': 5.95,
#   'Weight': 0.047,
#   'name': 'Paras Ice Gel',
#   'quantity': 5},
#  '1032': {'Category': 'Pen',
#   'Price': 34.15,
#   'Weight': 0.021,
#   'name': 'Classmate Pro blue',
#   'quantity': 97}}

# %%
for i in rec.values():
  print("Name : ",i["name"])
  print("Quantity : ",i["quantity"])
  print("Price : ",i["Price"])
  print("Category : ",i["Category"])
  print("Weight : ",i["Weight"])
  print("\n <--------------------------------------------------------------------> \n")
# Out:
# Name :  zandu Balm
# Quantity :  120
# Price :  80
# Category :  oniment
# Weight :  0.001
#
#  <-------------------------------------------------------------------->
#
# Name :  Raynolds Waterproff pen
# Quantity :  14
# Price :  10
# Category :  Pen
# Weight :  0.001
#
#  <-------------------------------------------------------------------->
#
# Name :  Wild Stone
# Quantity :  6
# Price :  300
# Category :  Talcum
# Weight :  0.25
#
#  <-------------------------------------------------------------------->
#
# Name :  Apple Cider vinegar
# Quantity :  73
# Price :  1.36
# Category :  drink
# Weight :  499.07
#
#  <-------------------------------------------------------------------->
#
# Name :  Pasta
# Quantity :  57
# Price :  40.32
# Category :  Snacks
# Weight :  0.53
#
#  <-------------------------------------------------------------------->
#
# Name :  Rice
# Quantity :  89
# Price :  889.17
# Category :  Food
# Weight :  0.71
#
#  <-------------------------------------------------------------------->
#
# Name :  Bread
# Quantity :  95
# Price :  10.99
# Category :  Food
# Weight :  77.35
#
#  <-------------------------------------------------------------------->
#
# Name :  All-purpose flour
# Quantity :  1
# Price :  739.14
# Category :  Food
# Weight :  2.91
#
#  <-------------------------------------------------------------------->
#
# Name :  Red kidney beans
# Quantity :  3
# Price :  2.54
# Category :  Food
# Weight :  0.19
#
#  <-------------------------------------------------------------------->
#
# Name :  White beans
# Quantity :  92
# Price :  790.18
# Category :  Food
# Weight :  0.09
#
#  <-------------------------------------------------------------------->
#
# Name :  Green lentils
# Quantity :  28
# Price :  0.59
# Category :  Food
# Weight :  0.07
#
#  <-------------------------------------------------------------------->
#
# Name :  Salt
# Quantity :  40
# Price :  0.79
# Category :  Spices
# Weight :  0.09
#
#  <-------------------------------------------------------------------->
#
# Name :  Pepper
# Quantity :  68
# Price :  3.27
# Category :  Spices
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Basil
# Quantity :  50
# Price :  303.32
# Category :  Spices
# Weight :  0.1
#
#  <-------------------------------------------------------------------->
#
# Name :  Oregano
# Quantity :  15
# Price :  36.64
# Category :  Spices
# Weight :  7.51
#
#  <-------------------------------------------------------------------->
#
# Name :  Coriander
# Quantity :  87
# Price :  696.98
# Category :  Spices
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Cumin
# Quantity :  29
# Price :  6.11
# Category :  Spices
# Weight :  7.25
#
#  <-------------------------------------------------------------------->
#
# Name :  Stock cubes
# Quantity :  12
# Price :  1.53
# Category :  Spices
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Honey
# Quantity :  66
# Price :  45.1
# Category :  Snacks
# Weight :  916.78
#
#  <-------------------------------------------------------------------->
#
# Name :  Vinegar
# Quantity :  65
# Price :  76.56
# Category :  drink
# Weight :  478.76
#
#  <-------------------------------------------------------------------->
#
# Name :  Sugar
# Quantity :  99
# Price :  78.84
# Category :  Food
# Weight :  2.98
#
#  <-------------------------------------------------------------------->
#
# Name :  Milk
# Quantity :  95
# Price :  1.75
# Category :  drink
# Weight :  0.7
#
#  <-------------------------------------------------------------------->
#
# Name :  Eggs
# Quantity :  23
# Price :  0.33
# Category :  Food
# Weight :  35.41
#
#  <-------------------------------------------------------------------->
#
# Name :  Cheese
# Quantity :  96
# Price :  19.27
# Category :  Food
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Yogurt
# Quantity :  64
# Price :  881.65
# Category :  Food
# Weight :  0.95
#
#  <-------------------------------------------------------------------->
#
# Name :  Cooking oil
# Quantity :  30
# Price :  1.87
# Category :  drink
# Weight :  2.06
#
#  <-------------------------------------------------------------------->
#
# Name :  Butter
# Quantity :  92
# Price :  836.22
# Category :  Food
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Stencil
# Quantity :  70
# Price :  5.55
# Category :  Decoration
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Hour Glass
# Quantity :  69
# Price :  9.65
# Category :  Decoration
# Weight :  56.15
#
#  <-------------------------------------------------------------------->
#
# Name :  Guitar
# Quantity :  32
# Price :  507.07
# Category :  Decoration
# Weight :  0.09
#
#  <-------------------------------------------------------------------->
#
# Name :  Action Figurine
# Quantity :  7
# Price :  955.71
# Category :  Decoration
# Weight :  0.0
#
#  <-------------------------------------------------------------------->
#
# Name :  Paras Ice Gel
# Quantity :  5
# Price :  5.95
# Category :  Pen
# Weight :  0.047
#
#  <-------------------------------------------------------------------->
#
# Name :  Classmate Pro blue
# Quantity :  97
# Price :  34.15
# Category :  Pen
# Weight :  0.021
#
#  <-------------------------------------------------------------------->
